# %%
import huggingface_hub
from huggingface_hub import HfApi

# %%
huggingface_hub.login(token = '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')

# %%
# 1. Instantiate the API
api = HfApi()

# repo_id = "YOUR_USER_NAME/iris"
repo_id = "victortomeno/iris26"
api.create_repo(repo_id=repo_id, repo_type="dataset")
# Out:
# RepoUrl('https://huggingface.co/datasets/victortomeno/iris26', endpoint='https://huggingface.co', repo_type='dataset', repo_id='victortomeno/iris26')

# %%
# 2. Upload the file
api.upload_file(
    path_or_fileobj="iris-HF/Iris.csv",        # Local path to your CSV
    path_in_repo="Iris.csv",           # File name/path in the repository
    repo_id= repo_id,     # The dataset repository on HF
    repo_type="dataset",               # repo_type="dataset" for a dataset repo
    # token="hf_your_token_here"         # Your personal HF token (not needed, because you're already logged in)
)

print("iris.csv uploaded successfully!")
# Out:
# iris.csv uploaded successfully!

# %%
from huggingface_hub import HfApi

api = HfApi()
repo_id = "victortomeno/iris-dataset"

api.create_repo(repo_id=repo_id, repo_type="dataset", exist_ok=True)
# Out:
# RepoUrl('https://huggingface.co/datasets/victortomeno/iris-dataset', endpoint='https://huggingface.co', repo_type='dataset', repo_id='victortomeno/iris-dataset')

# %%
api.upload_file(
    path_or_fileobj="Iris.csv",
    path_in_repo="iris.csv",
    repo_id=repo_id,
    repo_type="dataset"
)
# Out:
# CommitInfo(commit_url='https://huggingface.co/datasets/victortomeno/iris-dataset/commit/70456b24e01c08292b31661fce23885c94eb888d', commit_message='Upload iris.csv with huggingface_hub', commit_description='', oid='70456b24e01c08292b31661fce23885c94eb888d', pr_url=None, repo_url=RepoUrl('https://huggingface.co/datasets/victortomeno/iris-dataset', endpoint='https://huggingface.co', repo_type='dataset', repo_id='victortomeno/iris-dataset'), pr_revision=None, pr_num=None)

# %%
readme_content = """
# Iris Dataset
Dataset para el tutorial de MLOps de clasificacion de la especie Iris.
"""

with open("README.md", "w") as f:
    f.write(readme_content)

api.upload_file(
    path_or_fileobj="README.md",
    path_in_repo="README.md",
    repo_id=repo_id,
    repo_type="dataset"
)
# Out:
# c:\Users\Victor\anaconda3\Lib\site-packages\huggingface_hub\hf_api.py:9662: UserWarning: Warnings while validating metadata in README.md:
# - empty or missing yaml metadata in repo card
#   warnings.warn(f"Warnings while validating metadata in README.md:\n{message}")
# CommitInfo(commit_url='https://huggingface.co/datasets/victortomeno/iris-dataset/commit/62de45a0fdacdbe4e420d2549e7300eb99c060eb', commit_message='Upload README.md with huggingface_hub', commit_description='', oid='62de45a0fdacdbe4e420d2549e7300eb99c060eb', pr_url=None, repo_url=RepoUrl('https://huggingface.co/datasets/victortomeno/iris-dataset', endpoint='https://huggingface.co', repo_type='dataset', repo_id='victortomeno/iris-dataset'), pr_revision=None, pr_num=None)
